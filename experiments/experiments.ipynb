# %%
import json
json_string = '{"name": "John", "age": 30, "city": "New York"}'
data = json.loads(json_string)

print(data["name"])  # Output: John
# Out:
# John

# %%
import pandas as pd
convo_path = "conversations-000.json"
with open(convo_path, 'r') as file:
    conversations = json.load(file)

# %%
conversations_df = pd.DataFrame(conversations)

# %%
conversations_df
# Out:
#                          conversation_id  \
# 0   1225ed82-b3e0-409e-ae23-ea6e0fb201d6
# 1   66dc7e27-a9f0-8012-9bb7-70a5d6d9e9b5
# 2   66deee40-b8c4-8012-958d-ea06a308ff7d
# 3   66defe67-b4cc-8012-a1b6-cc3c2b54340c
# 4   66fb0374-80e0-8012-ae02-007411a3b0ca
# ..                                   ...
# 95  69009247-a7a0-8322-9467-c09293fac5a8
# 96  6901826b-3220-8321-ac70-e912b3baddc1
# 97  69084e80-539c-8321-b172-ec97bd5df23c
# 98  6908e97f-2098-8320-b2f3-ec1903478bbf
# 99  692ecb64-8840-8333-b5ad-44f888ea3e82
#
#                 conversation_template_id   create_time  \
# 0                                    NaN  1.722276e+09
# 1                                    NaN  1.725726e+09
# 2                                    NaN  1.725886e+09
# 3                                    NaN  1.725890e+09
# 4                                    NaN  1.727726e+09
# ..                                   ...           ...
# 95                                   NaN  1.761645e+09
# ...

# %%
conversations[0].keys()
# Out:
# dict_keys(['conversation_id', 'conversation_template_id', 'create_time', 'current_node', 'default_model_slug', 'id', 'is_archived', 'is_do_not_remember', 'is_read_only', 'is_starred', 'is_study_mode', 'is_temporary_chat', 'mapping', 'memory_scope', 'pinned_time', 'plugin_ids', 'title', 'update_time', 'voice'])

# %%
conversations[0]
# Out:
# {'conversation_id': '1225ed82-b3e0-409e-ae23-ea6e0fb201d6',
#  'conversation_template_id': None,
#  'create_time': 1722275501.785494,
#  'current_node': 'de5c493f-3d54-49f4-b194-59e52006707f',
#  'default_model_slug': 'gpt-4o',
#  'id': '1225ed82-b3e0-409e-ae23-ea6e0fb201d6',
#  'is_archived': False,
#  'is_do_not_remember': None,
#  'is_read_only': None,
#  'is_starred': None,
#  'is_study_mode': False,
#  'is_temporary_chat': False,
#  'mapping': {'97ed2527-7c63-480c-a236-c7d92b2f860b': {'id': '97ed2527-7c63-480c-a236-c7d92b2f860b',
#    'message': {'author': {'name': None, 'role': 'system'},
#     'content': {'content_type': 'text', 'parts': ['']},
#     'create_time': None,
#     'id': '97ed2527-7c63-480c-a236-c7d92b2f860b',
#     'metadata': {'can_save': False}},
#    'parent': 'aaa1435a-1899-43b8-b4c6-14bae5e54aeb'},
#   'aaa1435a-1899-43b8-b4c6-14bae5e54aeb': {'id': 'aaa1435a-1899-43b8-b4c6-14bae5e54aeb',
#    'message': None,
#    'parent': None},
# ...
